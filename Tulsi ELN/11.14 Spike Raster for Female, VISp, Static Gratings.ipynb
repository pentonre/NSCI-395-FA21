# %% [markdown]
# # Notebook #1
#
#
# ### Name: Tulsi Patel
#
#
# ### Date: 10.27.2021
#
#
# ### PID: 730392259
#
#
# ### Goal: Filter and create a spike raster for Sst-IRES/Female/VISp/Natural Scenes in Brain Observatory 1.1.

# %% [markdown]
# ## Protocol
#
# ### Starting code.

# %%
import os

import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter

from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache
from allensdk.brain_observatory.ecephys.ecephys_session import (
    EcephysSession
)
from allensdk.brain_observatory.ecephys.visualization import plot_mean_waveforms, plot_spike_counts, raster_plot
from allensdk.brain_observatory.visualization import plot_running_speed

# tell pandas to show all columns when we display a DataFrame
pd.set_option("display.max_columns", None)

# %%
data_directory = '/Users/tulsipatel/local1/ecephys_cache_dir' 
# must be updated to a valid directory in your filesystem

manifest_path = os.path.join(data_directory, "manifest.json")

# %%
cache = EcephysProjectCache.from_warehouse(manifest=manifest_path)

# %%
cache.get_session_table().head()
# Out:
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 732592105  2019-10-03T00:00:00Z    717038288  brain_observatory_1.1
# 737581020  2019-10-03T00:00:00Z    718643567  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 732592105        100.0   M                                            wt/wt
# 737581020        108.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 732592105         824           1847            5
# 737581020         568           2218            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 732592105       [grey, VISpm, nan, VISp, VISl, VISal, VISrl]
# 737581020      [grey, VISmma, nan, VISpm, VISp, VISl, VISrl]

# %%
sessions = cache.get_session_table()


print('Total number of sessions: ' + str(len(sessions)))

sessions.head()
# Out:
# Total number of sessions: 58
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 732592105  2019-10-03T00:00:00Z    717038288  brain_observatory_1.1
# 737581020  2019-10-03T00:00:00Z    718643567  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 732592105        100.0   M                                            wt/wt
# 737581020        108.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 732592105         824           1847            5
# 737581020         568           2218            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 732592105       [grey, VISpm, nan, VISp, VISl, VISal, VISrl]
# 737581020      [grey, VISmma, nan, VISpm, VISp, VISl, VISrl]

# %% [markdown]
# ### Filtering: Brain Observatory 1.1 -- Sst-IRES mice -- Female -- VISp

# %%
filtered_sessions = sessions[(sessions.sex == 'F') & \
                             (sessions.full_genotype.str.find('Pvalb-IRES-Cre') > -1) & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['VISp' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

filtered_sessions.head()
# Out:
#                    published_at  specimen_id           session_type  \
# id
# 746083955  2019-10-03T00:00:00Z    726170935  brain_observatory_1.1
# 773418906  2019-10-03T00:00:00Z    757329624  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 746083955         98.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 773418906        124.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 746083955         582           2216            6
# 773418906         546           2232            6
#
#                                   ecephys_structure_acronyms
# id
# 746083955  [VPM, TH, LGd, CA3, CA2, CA1, VISal, nan, grey...
# 773418906  [PPT, NOT, SUB, ProS, CA1, VISam, nan, APN, DG...

# %% [markdown]
# ### Stimulus-specific metrics that are computed for each unit.
#
# #### Applies filters and returns values above a specific threshold.
#
# Link about quality metrics: https://allensdk.readthedocs.io/en/latest/_static/examples/nb/ecephys_quality_metrics.ipynb

# %%
analysis_metrics1 = cache.get_unit_analysis_metrics_by_session_type('brain_observatory_1.1')
print(str(len(analysis_metrics1)) + ' units in table 1')
# Out:
# 21842 units in table 1

# %% [markdown]
# ### Downloading the data in one session.
#
# #### In one session, a mouse undergoes the entire stimulus set in Brain Observatory 1.1.
#
# #### Contains Static Set and Moving Set.
#
# #### Static Set has many individual static images. Moving Set has many individual movies.
#
# # XXX filter the session (from filtered session) to only include VISp in the ecephys structure acronyms

# %%
session = cache.get_session_data(filtered_sessions.index.values[0],
                                 isi_violations_maximum = np.inf,
                                 amplitude_cutoff_maximum = np.inf,
                                 presence_ratio_minimum = -np.inf
                                )

print([attr_or_method for attr_or_method in dir(session) if attr_or_method[0] != '_'])
# Out:
# WARNING:root:downloading a 2443.380MiB file from http://api.brain-map.org//api/v2/well_known_file_download/1026124262
# Downloading:   0%|          | 0.00/2.56G [00:00<?, ?B/s]

# %% [markdown]
# ## Finding the Static Set in the session. From this point onward, my code branches to try to find the firing rates/spikes of the units during the Static Set.

# %%
session.get_stimulus_table(['natural_scenes']).head()
# Out:
#                          frame   start_time stimulus_block   stimulus_name  \
# stimulus_presentation_id
# 51355                       92  5903.685974              9  natural_scenes
# 51356                       72  5903.936190              9  natural_scenes
# 51357                       43  5904.186405              9  natural_scenes
# 51358                       15  5904.436620              9  natural_scenes
# 51359                       44  5904.686836              9  natural_scenes
#
#                             stop_time  duration  stimulus_condition_id
# stimulus_presentation_id
# 51355                     5903.936190  0.250215                   4908
# 51356                     5904.186405  0.250215                   4909
# 51357                     5904.436620  0.250215                   4910
# 51358                     5904.686836  0.250215                   4911
# 51359                     5904.937048  0.250212                   4912

# %% [markdown]
# # #1
#
# ## Trying to look at units in only the Static Set. Find firing rates. Average firing rates in all units during the natural scenes stimulus.

# %%
natural_scenes_set = session.get_stimulus_table(['natural_scenes']).head()

# %%
natural_scenes_set.units.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7e948f565d30> in <module>
# ----> 1 natural_scenes_set.units.head()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'units'

# %% [markdown]
# # #2
#
# ## Creating a Raster plot for spikes that occured in units that had a firing rate > 0 during the natural scenes set .

# %%
session.get_stimulus_table(['natural_scenes']).head()
# Out:
#                          frame   start_time stimulus_block   stimulus_name  \
# stimulus_presentation_id
# 51355                       92  5903.685974              9  natural_scenes
# 51356                       72  5903.936190              9  natural_scenes
# 51357                       43  5904.186405              9  natural_scenes
# 51358                       15  5904.436620              9  natural_scenes
# 51359                       44  5904.686836              9  natural_scenes
#
#                             stop_time  duration  stimulus_condition_id
# stimulus_presentation_id
# 51355                     5903.936190  0.250215                   4908
# 51356                     5904.186405  0.250215                   4909
# 51357                     5904.436620  0.250215                   4910
# 51358                     5904.686836  0.250215                   4911
# 51359                     5904.937048  0.250212                   4912

# %%
session.units.head()
# Out:
#            amplitude_cutoff  waveform_recovery_slope  cluster_id  \
# unit_id
# 951791812          0.363284                -0.083245           1
# 951791801          0.500000                -0.088516           0
# 951791829          0.000988                -0.181799           2
# 951791844          0.003398                -0.130621           3
# 951791868          0.001211                -0.117704           5
#
#            waveform_spread  waveform_velocity_below   d_prime  nn_miss_rate  \
# unit_id
# 951791812             50.0                      NaN  4.737422      0.018963
# 951791801             50.0                      NaN  3.997947      0.005049
# 951791829             50.0                 0.000000  8.716975      0.000161
# 951791844             70.0                 0.000000  4.807868      0.008475
# 951791868             60.0                -0.343384  4.381891      0.020884
#
#            isolation_distance  silhouette_score  waveform_halfwidth  \
# unit_id
# 951791812          111.664739          0.056546            0.178559
# 951791801           25.810828               NaN            0.109883
# 951791829          135.492613          0.217727            0.123618
# 951791844           93.539639          0.177306            0.096147
# 951791868           93.768051          0.093410            0.137353
#
#            waveform_PT_ratio  cumulative_drift  isi_violations  \
# unit_id
# 951791812           0.600519            323.81        0.006886
# 951791801           0.401201            405.83        0.044313
# 951791829           0.648620            200.84        0.014226
# 951791844           0.618598            235.14        0.004809
# 951791868           0.606729            173.64        0.009742
#
#            presence_ratio       snr       L_ratio  waveform_amplitude  \
# unit_id
# 951791812            0.99  2.740140  6.753431e-03           61.807980
# 951791801            0.99  3.065164  3.630106e-02           32.163495
# 951791829            0.99  4.157949  3.424282e-09          149.179095
# 951791844            0.99  3.271097  6.448362e-03           98.237100
# 951791868            0.99  3.244161  9.937440e-03          105.767415
#
#            waveform_repolarization_slope  local_index_unit  \
# unit_id
# 951791812                       0.415647                 1
# 951791801                       0.450156                 0
# 951791829                       0.646620                 2
# 951791844                       0.375456                 3
# 951791868                       0.462754                 5
#
#            waveform_velocity_above  nn_hit_rate  peak_channel_id  \
# unit_id
# 951791812                 0.961474     0.983333        850090592
# 951791801                -0.137353     0.803333        850090592
# 951791829                -0.206030     1.000000        850090598
# 951791844                -0.137353     0.974000        850090604
# 951791868                 0.137353     0.970667        850090608
#
#            waveform_duration  firing_rate  max_drift  c50_dg  area_rf  \
# unit_id
# 951791812           0.233501    33.850010      34.40     NaN    300.0
# 951791801           0.206030     6.197023      17.92     NaN    200.0
# 951791829           0.192295    31.500639      25.73     NaN    200.0
# 951791844           0.178559    38.571969      29.65     NaN    600.0
# 951791868           0.178559    36.415146      26.10     NaN    800.0
#
#             fano_dg   fano_fl   fano_ns   fano_rf   fano_sg  f1_f0_dg  \
# unit_id
# 951791812  1.854083  1.273707  1.404108  1.498148  0.743842  0.152473
# 951791801  2.993939  1.037389  1.332830  1.123810  1.242347  0.457912
# 951791829  3.813358  0.693333  3.966638  1.281982  6.984628  0.183702
# 951791844  0.955155  0.722449  0.960036  1.108425  0.876520  0.112999
# 951791868  6.303737  1.565957  2.194863  2.444444  4.075222  0.226879
#
#            g_dsi_dg  g_osi_dg  g_osi_sg  azimuth_rf  mod_idx_dg  p_value_rf  \
# unit_id
# 951791812  0.025496  0.018580  0.012816      13.333    1.112148       0.704
# 951791801  0.035726  0.017616  0.049555      35.000    1.025586       0.018
# 951791829  0.029445  0.013855  0.033660      35.000    0.022935       0.971
# 951791844  0.017166  0.012749  0.013761      35.000    0.773651       0.046
# 951791868  0.008678  0.024218  0.016777      75.000    0.629035       0.449
#
#            pref_sf_sg  pref_tf_dg  run_mod_dg  run_mod_fl  run_mod_ns  \
# unit_id
# 951791812        0.32        15.0    0.175341    0.303538    0.215023
# 951791801        0.04        15.0    0.378486    0.140625    0.712418
# 951791829        0.02         8.0   -0.260148    0.218472    0.244552
# 951791844        0.16         4.0    0.107106    0.142094    0.135645
# 951791868        0.08         2.0   -0.230550   -0.300395   -0.302802
#
#            run_mod_rf  run_mod_sg  pref_ori_dg  pref_ori_sg  run_pval_dg  \
# unit_id
# 951791812         NaN    0.154948         45.0         90.0     0.011242
# 951791801    1.000000    0.704338        135.0         60.0     0.172660
# 951791829         NaN   -0.152564        135.0         90.0     0.314881
# 951791844   -0.191860    0.127236         45.0         30.0     0.106669
# 951791868   -0.441741   -0.467807          0.0          0.0     0.025760
#
#            run_pval_fl  run_pval_ns  run_pval_rf  run_pval_sg  elevation_rf  \
# unit_id
# 951791812     0.145526     0.133354          NaN     0.101531        46.667
# 951791801     0.521968     0.000043     0.000029     0.000053        50.000
# 951791829     0.076900     0.064436          NaN     0.771675       -30.000
# 951791844     0.164823     0.278626     0.505496     0.315617        10.000
# 951791868     0.192805     0.006803     0.005356     0.000061        25.000
#
#            pref_image_ns  pref_phase_sg  firing_rate_dg  firing_rate_fl  \
# unit_id
# 951791812           4927            0.0       32.537711       39.407561
# 951791801           5008            0.5        7.486586        6.927631
# 951791829           5014            0.5       31.102239       32.879601
# 951791844           4930            0.5       38.229295       36.689798
# 951791868           5017            0.0       36.962734       35.330917
#
#            firing_rate_ns  firing_rate_rf  firing_rate_sg  on_off_ratio_fl  \
# unit_id
# 951791812       31.408360       44.307253       30.054871              NaN
# 951791801        6.266357        5.679855        4.814641              NaN
# 951791829       31.817430       33.087895       30.247377              NaN
# 951791844       39.810075       38.408099       38.312633              NaN
# 951791868       36.518038       33.968382       37.322128              NaN
#
#            time_to_peak_ns  pref_sf_multi_sg  pref_tf_multi_dg  \
# unit_id
# 951791812           0.1245             False             False
# 951791801           0.0125             False             False
# 951791829           0.0155             False             False
# 951791844           0.0315             False             False
# 951791868           0.1415             False             False
#
#            pref_ori_multi_dg  pref_ori_multi_sg  pref_phase_multi_sg  \
# unit_id
# 951791812              False              False                False
# 951791801              False              False                False
# 951791829              False              False                False
# 951791844              False              False                False
# 951791868              False              False                False
#
#            image_selectivity_ns  pref_image_multi_ns  lifetime_sparseness_dg  \
# unit_id
# 951791812              0.097102                 True                0.002907
# 951791801              0.066644                False                0.016959
# 951791829              0.071593                False                0.002935
# 951791844              0.024339                False                0.002119
# 951791868             -0.051458                False                0.004566
#
#            lifetime_sparseness_fl  lifetime_sparseness_ns  \
# unit_id
# 951791812                0.007216                0.002415
# 951791801                0.019802                0.015459
# 951791829                0.000257                0.002868
# 951791844                0.000381                0.001555
# 951791868                0.008378                0.006339
#
#            lifetime_sparseness_rf  lifetime_sparseness_sg  \
# unit_id
# 951791812                0.006688                0.003828
# 951791801                0.043870                0.021987
# 951791829                0.006018                0.003118
# 951791844                0.005764                0.002682
# 951791868                0.017257                0.006285
#
#            probe_vertical_position  probe_horizontal_position   probe_id  \
# unit_id
# 951791812                       40                         59  769322820
# 951791801                       40                         59  769322820
# 951791829                       60                         11  769322820
# 951791844                      100                         43  769322820
# 951791868                      120                         59  769322820
#
#            channel_local_index  ecephys_structure_id  \
# unit_id
# 951791812                    2                   8.0
# 951791801                    2                   8.0
# 951791829                    5                   8.0
# 951791844                    8                   8.0
# 951791868                   10                   8.0
#
#           ecephys_structure_acronym  anterior_posterior_ccf_coordinate  \
# unit_id
# 951791812                      grey                                NaN
# 951791801                      grey                                NaN
# 951791829                      grey                                NaN
# 951791844                      grey                                NaN
# 951791868                      grey                                NaN
#
#            dorsal_ventral_ccf_coordinate  left_right_ccf_coordinate  \
# unit_id
# 951791812                            NaN                        NaN
# 951791801                            NaN                        NaN
# 951791829                            NaN                        NaN
# 951791844                            NaN                        NaN
# 951791868                            NaN                        NaN
#
#           probe_description                 location  probe_sampling_rate  \
# unit_id
# 951791812            probeA  See electrode locations         29999.970056
# 951791801            probeA  See electrode locations         29999.970056
# 951791829            probeA  See electrode locations         29999.970056
# 951791844            probeA  See electrode locations         29999.970056
# 951791868            probeA  See electrode locations         29999.970056
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 951791812              1249.998752                True
# 951791801              1249.998752                True
# 951791829              1249.998752                True
# 951791844              1249.998752                True
# 951791868              1249.998752                True

# %% [markdown]
# # go to lit. find a threshold firing rate that makes a unit "good". look at link in

# %%
# how many units have firing rates that are greater than 0?
print(f'{session.units.shape[0]} units total')
units_with_firing_rate = session.units[session.units['firing_rate'] > 0]
print(f'{units_with_firing_rate.shape[0]} units have firing rate > 0')
# Out:
# 1785 units total
# 1785 units have firing rate > 0

# %%
 # grab an arbitrary unit (we made units_with_firing_rates above)
firing_rate_unit_ids = units_with_firing_rate.index.values
unit_id = firing_rate_unit_ids[0]

print(f"{len(session.spike_times[unit_id])} spikes were detected for unit {unit_id} at times:")
session.spike_times[unit_id]
# Out:
# 328044 spikes were detected for unit 951791812 at times:
# array([3.75825042e+00, 3.77545044e+00, 3.81408381e+00, ...,
#        9.69481076e+03, 9.69482129e+03, 9.69484109e+03])

# %% [markdown]
# ## Raster Plot for Sst-IRES Female VISp Natural Scenes

# %%
# get spike times from the first block of natural scenes presentations 
natural_scenes_presentation_ids = session.stimulus_presentations.loc[
    (session.stimulus_presentations['stimulus_name'] == 'natural_scenes')
].index.values

times = session.presentationwise_spike_times(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=firing_rate_unit_ids
)

times.head()

# %%
first_natural_scene_presentation_id = times['stimulus_presentation_id'].values[0]
plot_times = times[times['stimulus_presentation_id'] == first_natural_scene_presentation_id]

fig = raster_plot(plot_times, title=f'spike raster for stimulus presentation {first_natural_scene_presentation_id}')
plt.show()

# also print out this presentation
session.stimulus_presentations.loc[first_natural_scene_presentation_id]

# %% [markdown]
# ## Resources Used
# https://allensdk.readthedocs.io/en/latest/visual_coding_neuropixels.html
# https://allensdk.readthedocs.io/en/latest/_static/examples/nb/ecephys_data_access.html
# https://allensdk.readthedocs.io/en/latest/_static/examples/nb/ecephys_session.html#Stimulus-presentations
